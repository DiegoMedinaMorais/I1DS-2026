# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoMedinaMorais/I1DS-2026/blob/main/Script_de_apresenta%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá mundo")
# Out:
# Olá mundo

# %% [markdown]
# # Esse é o link de nível 1

# %% [markdown]
# ## Esse é o link de nível 2

# %% [markdown]
# # Conceitos básicos

# %%
x = 5

# %%
print(x)
# Out:
# 5

# %%
x * 6
# Out:
# 30

# %%
x = 17
if x == 5:
  print("O número é 5")
else:
  print("O número não é 5")
# Out:
# O número não é 5

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
x = "Essa é uma string"
print(x)
# Out:
# Essa é uma string

# %%
x = [1, 2, 3, 4, 5, "teste", 6, 7, 8, 9]

# %%
for i in x:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# teste
# 6
# 7
# 8
# 9

# %%
aux = 10
while aux > 0:
 print("Ainda é verdade")
 print("Valor aux é:", aux)
 aux = aux - 1
# Out:
# Ainda é verdade
# Valor aux é: 10
# Ainda é verdade
# Valor aux é: 9
# Ainda é verdade
# Valor aux é: 8
# Ainda é verdade
# Valor aux é: 7
# Ainda é verdade
# Valor aux é: 6
# Ainda é verdade
# Valor aux é: 5
# Ainda é verdade
# Valor aux é: 4
# Ainda é verdade
# Valor aux é: 3
# Ainda é verdade
# Valor aux é: 2
# Ainda é verdade
# Valor aux é: 1

# %% [markdown]
# # Biblioteca request

# %%
import requests
from google.colab import userdata

# API key
API_KEY = userdata.get('GROQ_API_KEY')

# Endpoint
url = "https://api.groq.com/openai/v1/chat/completions"

# Headers
headers = {
    "Content-Type":"application/json",
    "Authorization":f"Bearer {API_KEY}"
}

# Dados de requisição
data = {
    "model": "llama-3.3-70b-versatile",
    "messages": [
        {
            "role": "user",
            "content": "Explique o que é Cloud Computing em poucas palavras."
        }
    ],
    "temperature": 0.7
}

# Requisição
response = requests.post(url, headers=headers, json=data)

# Resposta
if response.status_code == 200:
  resposta = response.json()
  print(resposta["choices"][0]["message"]["content"])
else:
  print(f"Erro: {response.status_code}")
  print(response.text)
# Out:
# Cloud Computing é um modelo de entrega de serviços de tecnologia da informação via internet, onde os recursos de computação, armazenamento e software são fornecidos como serviços on-demand.
